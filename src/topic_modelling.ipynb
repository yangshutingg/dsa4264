# %%
# Install necessary libraries
# !pip install bertopic

# %%
import pandas as pd
from bertopic import BERTopic
from bertopic.representation import KeyBERTInspired

# %%
import os

# Disable HuggingFace tokenizers parallelism warning
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
df = pd.read_csv('../data/combined_data_scores.csv')
df = df[['text', 'yearmonth', 'title', 'index', 'average_toxicity_score']]

# %% [markdown]
# # BERTopic

# %% [markdown]
# ## Function to get topics for each yearmonth

# %%
def process_topics_by_year(df, year, output_csv, start_month = 1):
    """
    Process topics for all yearmonths in the specified year using BERTopic, and output results into a csv file.
    
    Parameters:
    - df: The original DataFrame containing the data.
    - year: The year for which to process the data (e.g., 2022).
    - output_csv: The output CSV file to save the results.
    - start_month: The starting month for processing (default is 1).
    
    """
    # Filter the DataFrame for the specified year
    df_filtered_year = df[df['yearmonth'].str.startswith(str(year))]

    # Get unique year-month combinations for the specified year
    unique_yearmonths = df_filtered_year['yearmonth'].unique()

    for idx, yearmonth in enumerate(unique_yearmonths):
        # Skip months before the start_month
        if int(yearmonth[-2:]) < start_month:
            continue
        else:
            print(f"Processing {yearmonth}...")
            
            # Filter data for the current year-month
            df_filtered = df[df['yearmonth'] == yearmonth]

            # Initialise representation model
            representation_model = KeyBERTInspired()

            # Initialize BERTopic model
            topic_model = BERTopic(representation_model=representation_model, nr_topics="auto")

            # Fit the model on the text data
            topics, probabilities = topic_model.fit_transform(df_filtered['text'])

            # Save topics per document
            df_topics = pd.DataFrame({
                'index': df_filtered['index'],
                'Topic': topics
            })

            # Save topic information (such as topic words and frequencies)
            topic_info = topic_model.get_topic_info()

            # Merge topics with original data
            df_combined = pd.merge(df_filtered, df_topics, on='index', how='left')

            # Merge topic info with the combined data
            df_final = pd.merge(df_combined, topic_info, on='Topic', how='left')

            # Write the result to the output CSV file
            if idx == 0:
                df_final.to_csv(output_csv, index=False, mode='w')  # Write header for the first batch
            else:
                df_final.to_csv(output_csv, index=False, mode='a', header=False)  # Append mode without header

            print(f"Processing for {yearmonth} is complete.")
            # for testing
            # break

# %% [markdown]
# ## Call the batch processing function

# %%
process_topics_by_year(df, year=2023, output_csv='../data/topics_2023.csv')

# %% [markdown]
# ## Combine topics for all years

# %% [markdown]
# # Evaluation of BERTopic on sample of data using Coherence Score
# Using `yearmonth` = `2023-10`

# %%
df_sample = df[df['yearmonth'] == '2023-10']

# %% [markdown]
# Initialise BERTopic model

# %%
# Create representation model
representation_model = KeyBERTInspired()

# Use the representation model in BERTopic on top of the default pipeline
topic_model = BERTopic(representation_model=representation_model, nr_topics='auto')

# Fit the model on text data
topics, probabilities = topic_model.fit_transform(df_sample['text'])

# %%
# Get the top 20 most frequent topics
topic_model.get_topic_info().head(20)
# Out:
#     Topic  Count                                             Name  \
# 0      -1  11183                              -1_be_say_life_than
# 1       0   2093  0_singaporeans_singapores_singaporean_singapore
# 2       1    701            1_gaza_palestinians_hamas_palestinian
# 3       2    638                    2_roads_lanes_driving_cyclist
# 4       3    423                      3_crimes_raped_rape_accused
# 5       4    318                        4_rice_chicken_meals_food
# 6       5    295                    5_banking_bank_banks_citibank
# 7       6    270                               6_siao_lang_sia_si
# 8       7    255                   7_voting_opposition_vote_votes
# 9       8    201                  8_prices_affordable_btos_afford
# 10      9    199               9_revenge_bullying_bullied_bullies
# 11     10    175                          10_lol_lols_hahaha_haha
# 12     11    149           11_buddhists_buddhism_violence_violent
# 13     12    137                           12_pap_paps_papbut_psp
# 14     13    136                13_prc_mandarin_chinese_translate
# 15     14    134             14_sinkie_sinkies_sinkieland_sinking
# 16     15    129                             15_ns_nsf_nsfs_nsmen
# 17     16    128           16_feminism_feminist_feminists_genders
# 18     17    128       17_foreigners_migrant_foreigner_immigrants
# 19     18    127                               18_yes_yep_no_nope
#
#                                        Representation  \
# 0   [be, say, life, than, what, if, money, her, re...
# 1   [singaporeans, singapores, singaporean, singap...
# 2   [gaza, palestinians, hamas, palestinian, pales...
# 3   [roads, lanes, driving, cyclist, traffic, cycl...
# 4   [crimes, raped, rape, accused, crime, murder, ...
# 5   [rice, chicken, meals, food, meal, meat, foodp...
# 6   [banking, bank, banks, citibank, apps, account...
# 7   [siao, lang, sia, si, siala, langs, siew, kian...
# 8   [voting, opposition, vote, votes, voters, elec...
# 9   [prices, affordable, btos, afford, cost, bto, ...
# 10  [revenge, bullying, bullied, bullies, bully, r...
# 11  [lol, lols, hahaha, haha, hahah, hahahaha, lma...
# 12  [buddhists, buddhism, violence, violent, islam...
# 13  [pap, paps, papbut, psp, pe, tean, oppo, wp, s...
# 14  [prc, mandarin, chinese, translate, kwang, kar...
# 15  [sinkie, sinkies, sinkieland, sinking, pinkie,...
# 16  [ns, nsf, nsfs, nsmen, national, to, us, mates...
# 17  [feminism, feminist, feminists, genders, gende...
# 18  [foreigners, migrant, foreigner, immigrants, f...
# 19  [yes, yep, no, nope, yessir, yeah, yea, ya, na...
#
#                                   Representative_Docs
# 0   [First up, I want to tell you that it makes me...
# 1   [While some people (OP included) prefer to liv...
# 2   [Suddenly everyone is talking about the crimes...
# 3   [As a car driver, the only time I panic is whe...
# 4   [The point I'm making is that he compared two ...
# 5   [if chicken expensive eat fish la, Chicken ric...
# 6   [Have a million up votes my friend.\n\nI am 59...
# 7   [Knn siao lang, Siao lang, siao lang everywher...
# 8   [Vote opposition, Vote opposition, Vote opposi...
# 9   [Latest BTO Prices from $364,000 to $509,000 3...
# 10  [That is what I’m saying though, that I’ve “ma...
# 11                                    [Lol, Lol, LOL]
# 12  [I don’t know enough of all religions to make ...
# 13                  [Vote for pap, PAP so good., PAP]
# 14  [PRC Karen: 我不需要猜…eh?, Same as George Yeo, Lim...
# 15  [same old sinkie pwn sinkie mindset., Sinkie p...
# 16                                    [NS, Ns :(, NS]
# 17  [you have some really solid points! just to no...
# 18  [Spore good for accepting other nationalities ...
# 19                             [Yes, Yes, Yes and no]

# %%
topic_model.visualize_topics()

# %% [markdown]
# ## Coherence Score

# %%
import gensim.corpora as corpora
from gensim.models.coherencemodel import CoherenceModel

# Preprocess documents
cleaned_docs = topic_model._preprocess_text(df_sample['text'])

# Extract vectorizer and tokenizer from BERTopic
vectorizer = topic_model.vectorizer_model
tokenizer = vectorizer.build_tokenizer()

# Extract features for Topic Coherence evaluation
# words = vectorizer.get_feature_names()
tokens = [tokenizer(doc) for doc in cleaned_docs]
dictionary = corpora.Dictionary(tokens)
corpus = [dictionary.doc2bow(token) for token in tokens]
topic_words = [[words for words, _ in topic_model.get_topic(topic)] 
               for topic in range(len(set(topics))-1)]

# Evaluate
coherence_model = CoherenceModel(topics=topic_words, 
                                 texts=tokens, 
                                 corpus=corpus,
                                 dictionary=dictionary, 
                                 coherence='c_v')
coherence_model.get_coherence()
# Out:
# 0.3329467517487214
