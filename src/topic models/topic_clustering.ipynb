# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import networkx as nx
from collections import defaultdict
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm
from sklearn.neighbors import NearestNeighbors

# %%
df_2020 = pd.read_csv("D:\\Github_Repos\\dsa4264\\data\\topics_2020.csv")
df_2021 = pd.read_csv("D:\\Github_Repos\\dsa4264\\data\\topics_2021.csv")
df_2022 = pd.read_csv("D:\\Github_Repos\\dsa4264\\data\\topics_2022.csv")
df_2023 = pd.read_csv("D:\\Github_Repos\\dsa4264\\data\\topics_2023.csv")

# %%
df_2020.head()
# Out:
#                                                 text yearmonth  \
# 0  SUTD entry requirements is more or less the sa...   2020-01
# 1          With jam like this, it's barely worth it.   2020-01
# 2  I outside now, I guess reaching there around 0...   2020-01
# 3                            The female or male cry?   2020-01
# 4  bring an umbrella! it gets really hot during t...   2020-01
#
#                                               title  index  \
# 0                                  sit suss or sutd      0
# 1         how congested the ecp is on new years day      1
# 2    whats the earliest timing i can visit the guan      2
# 3  rsingapore random discussion and small questions      3
# 4   what is there to prepare for a trip to st johns      4
#
#    average_toxicity_score  Topic  Count  \
# 0                0.043735     29    213
# 1                0.034306    132     64
# 2                0.077415    343     27
# 3                0.029896    303     30
# 4                0.042127     -1  35897
#
#                                                 Name  \
# 0                               29_ns_nsf_nsmen_nsfs
# 1  132_pineapples_pineapple_pineappless_pineapple...
# 2                       343_slow_slower_speed_faster
# 3                         303_cry_crying_cried_cries
# 4                         -1_being_really_than_about
#
#                                       Representation  \
# 0  ['ns', 'nsf', 'nsmen', 'nsfs', 'nsrelated', 'n...
# 1  ['pineapples', 'pineapple', 'pineappless', 'pi...
# 2  ['slow', 'slower', 'speed', 'faster', '24mph',...
# 3  ['cry', 'crying', 'cried', 'cries', 'tears', '...
# 4  ['being', 'really', 'than', 'about', 'im', 'wi...
#
#                                  Representative_Docs
# 0                ['So...what is ns....', 'ns', 'Ns']
# 1  ['pineapple tarts are love, pineapple tarts ar...
# 2  ['So slow reaction time???.cfm not paying atte...
# 3  ["You should be more worried if she doesn't cr...
# 4  ["It is good that you care about your mum but ...

# %%
def extract_topic_features(dfs_dict):
    """
    Modified function to include toxicity score aggregation
    """
    topic_data = []
    
    for year, df in dfs_dict.items():
        print(f"Processing {year}...")
        for _, row in df.iterrows():
            try:
                # Handle keywords
                if isinstance(row['Name'], str):
                    if row['Name'].startswith('[') and row['Name'].endswith(']'):
                        keywords = eval(row['Name'])
                    else:
                        keywords = row['Name'].split('_')[1:]
                else:
                    continue
                
                # Handle Representative_Docs
                if isinstance(row['Representative_Docs'], str):
                    rep_docs = eval(row['Representative_Docs'])
                else:
                    rep_docs = row['Representative_Docs'] if isinstance(row['Representative_Docs'], list) else []
                
                keyword_str = ' '.join([str(k) for k in keywords if k and str(k).strip()])
                
                if keyword_str:
                    topic_data.append({
                        'year': year,
                        'yearmonth': row['yearmonth'],
                        'topic_id': row['Topic'],
                        'keywords': keyword_str,
                        'representative_docs': rep_docs,
                        'count': row.get('Count', 0),
                        'toxicity_score': row['average_toxicity_score']
                    })
            except Exception as e:
                print(f"Error processing row in {year}: {e}")
                continue
    
    return pd.DataFrame(topic_data)

# %%
# Create dataset
dfs_dict = {
    '2020': df_2020,
    '2021': df_2021,
    '2022': df_2022,
    '2023': df_2023
}

# Print initial stats
print("\nInitial Dataset Statistics:")
for year, df in dfs_dict.items():
    print(f"{year}: {len(df)} rows, {df['Topic'].nunique()} unique topics")

topics_df = extract_topic_features(dfs_dict)
print(f"\nExtracted {len(topics_df)} topic entries")
# Out:
# Initial Dataset Statistics:
# 2020: 1302526 rows, 1126 unique topics
# 2021: 1361253 rows, 1329 unique topics
# 2022: 1042831 rows, 1074 unique topics
# 2023: 797719 rows, 1002 unique topics
# Processing 2020...
# Processing 2021...
# Processing 2022...
# Processing 2023...
#
# Extracted 4501485 topic entries

# %%
topics_df.head()
# Out:
#    year yearmonth  topic_id                                          keywords  \
# 0  2020   2020-01        29                                 ns nsf nsmen nsfs
# 1  2020   2020-01       132  pineapples pineapple pineappless pineappleglazed
# 2  2020   2020-01       343                          slow slower speed faster
# 3  2020   2020-01       303                            cry crying cried cries
# 4  2020   2020-01        -1                           being really than about
#
#                                  representative_docs  count  toxicity_score
# 0                      [So...what is ns...., ns, Ns]    213        0.043735
# 1  [pineapple tarts are love, pineapple tarts are...     64        0.034306
# 2  [So slow reaction time???.cfm not paying atten...     27        0.077415
# 3  [You should be more worried if she doesn't cry...     30        0.029896
# 4  [It is good that you care about your mum but p...  35897        0.042127

# %%
def clean_topic_keywords(keywords_str):
    # Remove common stopwords and non-meaningful terms
    stopwords = {'than', 'being', 'how', 'will', 'what', 'why', 'when', 'who', 'where', 'about', 'really', 'very', 'just'}
    words = [w for w in keywords_str.split() if w.lower() not in stopwords and len(w) > 2]
    return ' '.join(words)

def get_meaningful_topics(topics_df, min_count=100, top_n_per_year=500):
    print("Processing meaningful topics...")
    
    # First, clean keywords
    topics_df['clean_keywords'] = topics_df['keywords'].apply(clean_topic_keywords)
    
    # Remove topics with empty or non-meaningful keywords
    filtered = topics_df[
        (topics_df['clean_keywords'].str.strip() != '') & 
        (topics_df['count'] >= min_count)
    ]
    print(f"After initial filtering: {len(filtered)} topics")
    
    # Remove duplicates based on year and clean_keywords
    filtered = filtered.drop_duplicates(subset=['year', 'clean_keywords'])
    print(f"After removing duplicates: {len(filtered)} topics")
    
    # Take top N most representative topics per year
    significant = filtered.groupby('year').apply(
        lambda x: x.nlargest(top_n_per_year, 'count')
    ).reset_index(drop=True)
    
    print(f"Final number of significant topics: {len(significant)}")
    
    # Print some statistics
    print("\nTopics per year:")
    print(significant.groupby('year').size())
    
    return significant

# %%
def preprocess_topics(topics_df):
    # More comprehensive stopwords
    generic_terms = {
        'singapore', 'singaporean', 'singaporeans', 'because', 'than', 'being', 'about',
        'really', 'very', 'just', 'like', 'get', 'got', 'much', 'many', 'more', 'also',
        'the', 'this', 'that', 'these', 'those', 'there', 'here', 'what', 'when', 'where',
        'who', 'why', 'how', 'which', 'way', 'not', 'can', 'will', 'would', 'should','her','she',
        'they', 'thank', 'thanks', 'thankyou', 'please', 'plz', 'help', 'need', 'want', 'wish',
        'yes','yess','nope'
    }
    
    def clean_keywords(text):
        # Normalize keywords
        words = set(text.lower().split())  # Convert to set to remove duplicates
        words = words - generic_terms  # Remove generic terms
        return ' '.join(sorted(words))  # Sort to make order irrelevant
    
    topics_df['clean_keywords'] = topics_df['clean_keywords'].apply(clean_keywords)
    
    # Remove topics with too few meaningful words
    topics_df = topics_df[topics_df['clean_keywords'].str.split().str.len() >= 2]
    
    return topics_df

# %%
meaningful_topics = get_meaningful_topics(topics_df, min_count=100, top_n_per_year=200)
meaningful_topics = preprocess_topics(meaningful_topics)

print("\nSample of meaningful topics:")
print(meaningful_topics[['year', 'topic_id', 'clean_keywords', 'count']].sort_values('count', ascending=False).head(20))
# Out:
# Processing meaningful topics...
# After initial filtering: 3474389 topics
# After removing duplicates: 3330 topics
# Final number of significant topics: 800
#
# Topics per year:
# year
# 2020    200
# 2021    200
# 2022    200
# 2023    200
# dtype: int64
#
# Sample of meaningful topics:
#      year  topic_id                        clean_keywords  count
# 0    2020        -1                        opposition pap  84568
# 200  2021        -1                            covid work  74628
# 202  2021        -1                       covid time work  64119
# 203  2021        -1                         chinese covid  61667
# 204  2021        -1                      covid vaccinated  60027
# 1    2020        -1                    government workers  58513
# 207  2021        -1  covid vaccinated vaccination vaccine  56142
# 3    2020        -1                              job work  53876
# 4    2020        -1                          job pay work  53387
# 9    2020         0                             dont work  44767
# 403  2022        -1                            covid work  44267
# 11   2020        -1                              job work  42212
# 12   2020        -1                           dont people  37608
# 608  2023        -1                            know their  33139
# 609  2023        -1                        life money pay  11208
# 215  2021         0                         covid covid19   7776
# 216  2021         0  covid covid19 vaccinated vaccination   6243
# 217  2021         0        covid pandemic sinovac vaccine   5800
# 410  2022         0                  bto btos hdb housing   2486
# 610  2023         0   gaza hamas palestinian palestinians   2271

# %%
def find_semantic_clusters(topics_df, min_similarity=0.6):
    # Vectorize with better parameters
    vectorizer = TfidfVectorizer(
        stop_words='english',
        ngram_range=(1, 2),  # Include bigrams
        min_df=2,  # Minimum document frequency
        max_df=0.9  # Maximum document frequency
    )
    
    vectors = vectorizer.fit_transform(topics_df['clean_keywords'])
    
    # Find similar topics
    nn = NearestNeighbors(n_neighbors=min(10, len(topics_df)), 
                         metric='cosine', 
                         algorithm='brute')
    nn.fit(vectors)
    distances, indices = nn.kneighbors(vectors)
    
    # Create graph with stricter similarity threshold
    G = nx.Graph()
    
    for i in range(len(topics_df)):
        G.add_node(i, 
                  year=topics_df.iloc[i]['year'],
                  keywords=topics_df.iloc[i]['clean_keywords'],
                  count=topics_df.iloc[i]['count'])
    
    for i in range(len(indices)):
        for j, dist in zip(indices[i][1:], distances[i][1:]):
            similarity = 1 - dist
            if similarity > min_similarity:
                G.add_edge(i, j, weight=similarity)
    
    # Use a different community detection algorithm
    communities = nx.community.greedy_modularity_communities(G)
    
    return communities, G, vectorizer.get_feature_names_out()

# %%
communities, G, feature_names = find_semantic_clusters(meaningful_topics, min_similarity=0.5)

# %%
def analyze_semantic_clusters(topics_df, communities):
    cluster_analysis = []
    
    for cluster_id, community in enumerate(communities):
        if len(community) < 2:
            continue
            
        cluster_topics = topics_df.iloc[list(community)]
        
        # Calculate cluster coherence
        keywords = ' '.join(cluster_topics['clean_keywords'])
        unique_keywords = set(keywords.split())
        
        # Get temporal evolution by month
        monthly_counts = cluster_topics.groupby('yearmonth')['count'].sum()
        temporal_evolution = {
            year: {
                f"{year}-{month:02d}": {
                    'post_count': monthly_counts.get(f"{year}-{month:02d}", 0)
                }
                for month in range(1, 13)
            }
            for year in cluster_topics['year'].unique()
        }
        
        # Calculate toxicity evolution by month
        toxicity_monthly = cluster_topics.groupby('yearmonth')['toxicity_score'].agg(['mean', 'count']).round(4)
        toxicity_evolution = {
            year: {
                month: {
                    'avg_toxicity': stats['mean'],
                    'post_count': stats['count']
                }
                for month, stats in toxicity_monthly[toxicity_monthly.index.str.startswith(year)].iterrows()
            }
            for year in cluster_topics['year'].unique()
        }
        
        # Calculate topic diversity
        topic_diversity = len(unique_keywords) / len(community)
        
        cluster_analysis.append({
            'cluster_id': cluster_id,
            'size': len(community),
            'total_posts': cluster_topics['count'].sum(),
            'unique_keywords': list(unique_keywords),
            'topic_diversity': topic_diversity,
            'temporal_evolution': temporal_evolution,
            'toxicity_evolution': toxicity_evolution,
            'avg_toxicity': cluster_topics['toxicity_score'].mean(),
            'sample_topics': cluster_topics.nlargest(3, 'count')['clean_keywords'].tolist(),
            'topic_indices': list(community)
        })
    
    return pd.DataFrame(cluster_analysis)

# %%
cluster_analysis = analyze_semantic_clusters(meaningful_topics, communities)

# %%
cluster_analysis.head()
# Out:
#    cluster_id  size  total_posts  \
# 0           0    22       141317
# 1           1    20        14679
# 2           2    17         9207
# 3           3    15         8096
# 4           4    12         7217
#
#                                      unique_keywords  topic_diversity  \
# 0  [viruses, covids, quarantines, coronavirus, si...         1.227273
# 1  [hdb, asset, sale, sell, rents, mortgage, bloc...         1.350000
# 2  [sgs, sgsecure, sgreans, sgd, sgraw, sgean, sg...         0.764706
# 3  [bikers, cyclists, cyclist, motorcyclists, ped...         1.133333
# 4  [masked, mask, maskless, masking, maskoff, mas...         0.750000
#
#                                   temporal_evolution  \
# 0  {'2021': {'2021-01': {'post_count': 0}, '2021-...
# 1  {'2021': {'2021-01': {'post_count': 384}, '202...
# 2  {'2022': {'2022-01': {'post_count': 0}, '2022-...
# 3  {'2023': {'2023-01': {'post_count': 291}, '202...
# 4  {'2020': {'2020-01': {'post_count': 0}, '2020-...
#
#                                   toxicity_evolution  avg_toxicity  \
# 0  {'2021': {'2021-05': {'avg_toxicity': 0.0441, ...      0.050925
# 1  {'2021': {'2021-01': {'avg_toxicity': 0.0461, ...      0.086916
# 2  {'2022': {'2022-07': {'avg_toxicity': 0.0595, ...      0.049124
# 3  {'2023': {'2023-01': {'avg_toxicity': 0.0416, ...      0.056845
# 4  {'2020': {'2020-08': {'avg_toxicity': 0.0425, ...      0.086982
#
#                                        sample_topics  \
# 0  [covid vaccinated, covid vaccinated vaccinatio...
# 1  [bto btos hdb housing, btos flats hdb valuatio...
# 2  [rsg sgraw sgs, sgeans sgraw sgs, sgraw sgs sg...
# 3  [driving pedestrian pedestrians traffic, drivi...
# 4  [mask masking maskoff masks, mask maskless mas...
#
#                                        topic_indices
# 0  [192, 321, 66, 195, 514, 388, 637, 653, 529, 8...
# 1  [194, 707, 196, 519, 712, 649, 703, 278, 603, ...
# 2  [481, 389, 425, 201, 75, 409, 587, 655, 559, 6...
# 3  [577, 70, 264, 9, 235, 14, 591, 497, 689, 52, ...
# 4  [128, 385, 223, 132, 267, 109, 302, 210, 406, ...

# %%
# sort by total_post
cluster_analysis.sort_values('total_posts', ascending=False).head(10)
# Out:
#     cluster_id  size  total_posts  \
# 56          56     3       183014
# 42          42     4       150279
# 0            0    22       141317
# 79          79     2        82375
# 9            9    10        65735
# 54          54     3        59198
# 1            1    20        14679
# 2            2    17         9207
# 3            3    15         8096
# 4            4    12         7217
#
#                                       unique_keywords  topic_diversity  \
# 56                                [covid, time, work]         1.000000
# 42                 [employment, jobs, pay, work, job]         1.250000
# 0   [viruses, covids, quarantines, coronavirus, si...         1.227273
# 79                               [people, dont, work]         1.500000
# 9   [mandarin, zhongguo, translation, korean, cant...         2.100000
# 54  [ndp, governments, govt, ndps, workers, gov, c...         2.666667
# 1   [hdb, asset, sale, sell, rents, mortgage, bloc...         1.350000
# 2   [sgs, sgsecure, sgreans, sgd, sgraw, sgean, sg...         0.764706
# 3   [bikers, cyclists, cyclist, motorcyclists, ped...         1.133333
# 4   [masked, mask, maskless, masking, maskoff, mas...         0.750000
#
#                                    temporal_evolution  \
# 56  {'2021': {'2021-01': {'post_count': 0}, '2021-...
# 42  {'2020': {'2020-01': {'post_count': 0}, '2020-...
# 0   {'2021': {'2021-01': {'post_count': 0}, '2021-...
# 79  {'2020': {'2020-01': {'post_count': 0}, '2020-...
# 9   {'2020': {'2020-01': {'post_count': 0}, '2020-...
# 54  {'2020': {'2020-01': {'post_count': 0}, '2020-...
# 1   {'2021': {'2021-01': {'post_count': 384}, '202...
# 2   {'2022': {'2022-01': {'post_count': 0}, '2022-...
# 3   {'2023': {'2023-01': {'post_count': 291}, '202...
# 4   {'2020': {'2020-01': {'post_count': 0}, '2020-...
#
#                                    toxicity_evolution  avg_toxicity  \
# 56  {'2021': {'2021-09': {'avg_toxicity': 0.0539, ...      0.042370
# 42  {'2020': {'2020-02': {'avg_toxicity': 0.0287, ...      0.039404
# 0   {'2021': {'2021-05': {'avg_toxicity': 0.0441, ...      0.050925
# 79  {'2020': {'2020-02': {'avg_toxicity': 0.0393, ...      0.033578
# 9   {'2020': {'2020-06': {'avg_toxicity': 0.2484, ...      0.055862
# 54  {'2020': {'2020-04': {'avg_toxicity': 0.0356, ...      0.039268
# 1   {'2021': {'2021-01': {'avg_toxicity': 0.0461, ...      0.086916
# 2   {'2022': {'2022-07': {'avg_toxicity': 0.0595, ...      0.049124
# 3   {'2023': {'2023-01': {'avg_toxicity': 0.0416, ...      0.056845
# 4   {'2020': {'2020-08': {'avg_toxicity': 0.0425, ...      0.086982
#
#                                         sample_topics  \
# 56          [covid work, covid time work, covid work]
# 42                 [job work, job pay work, job work]
# 0   [covid vaccinated, covid vaccinated vaccinatio...
# 79                           [dont work, dont people]
# 9   [chinese covid, cantonese chinese dialects man...
# 54  [government workers, gov government government...
# 1   [bto btos hdb housing, btos flats hdb valuatio...
# 2   [rsg sgraw sgs, sgeans sgraw sgs, sgraw sgs sg...
# 3   [driving pedestrian pedestrians traffic, drivi...
# 4   [mask masking maskoff masks, mask maskless mas...
#
#                                         topic_indices
# 56                                    [184, 369, 183]
# 42                                      [2, 3, 5, 22]
# 0   [192, 321, 66, 195, 514, 388, 637, 653, 529, 8...
# 79                                             [4, 6]
# 9      [41, 681, 44, 237, 304, 82, 53, 185, 442, 668]
# 54                                      [1, 282, 334]
# 1   [194, 707, 196, 519, 712, 649, 703, 278, 603, ...
# 2   [481, 389, 425, 201, 75, 409, 587, 655, 559, 6...
# 3   [577, 70, 264, 9, 235, 14, 591, 497, 689, 52, ...
# 4   [128, 385, 223, 132, 267, 109, 302, 210, 406, ...

# %%
# sort by average toxicity score
cluster_analysis.sort_values('avg_toxicity', ascending=False).head(20)
# Out:
#      cluster_id  size  total_posts  \
# 99           99     2         1118
# 142         142     2          797
# 141         141     2         1176
# 59           59     3         2486
# 134         134     2         1541
# 125         125     2         1173
# 31           31     6         3953
# 130         130     2          989
# 28           28     6         3338
# 61           61     3         1708
# 49           49     4         1596
# 26           26     6         2200
# 77           77     3          873
# 51           51     3         1658
# 112         112     2          693
# 36           36     5         2151
# 47           47     4         2567
# 27           27     6         2290
# 30           30     6         2498
# 50           50     4         2656
#
#                                        unique_keywords  topic_diversity  \
# 99          [cops, policeman, arrest, police, reports]         2.500000
# 142   [footballing, football, footballers, footballer]         2.000000
# 141                 [marijuana, cannabis, drugs, weed]         2.000000
# 59                   [crimea, ukraines, ukraine, nato]         1.333333
# 134     [role, nathan, tharman, tharmans, him, tharma]         3.000000
# 125      [funny, jokes, laughed, humor, comedic, joke]         3.000000
# 31   [homosexual, repeal, homosexuality, transgende...         2.000000
# 130  [filming, cctv, cctvs, camera, consent, camera...         3.500000
# 28   [wage, payouts, pays, income, unemployment, sa...         1.666667
# 61   [secular, christianity, religion, religious, r...         1.666667
# 49   [shanghai, chinese, beijing, chinas, prc, chin...         1.750000
# 26   [smoker, smokes, smokers, cigarettes, smoke, s...         1.500000
# 77   [driver, drivers, vehicles, driving, accident,...         2.333333
# 51   [millennials, boomery, millennial, boomer, boo...         2.000000
# 112              [burns, burned, burnt, burn, burning]         2.500000
# 36   [running, socks, shoe, shoes, footwear, sandal...         1.600000
# 47   [teaching, teachers, student, classrooms, thre...         2.250000
# 27   [patriarchy, masculinity, feminists, feminist,...         1.333333
# 30   [accusations, accused, accusation, innocence, ...         2.500000
# 50   [leases, landlords, rental, landlord, renting,...         2.000000
#
#                                     temporal_evolution  \
# 99   {'2020': {'2020-01': {'post_count': 0}, '2020-...
# 142  {'2023': {'2023-01': {'post_count': 273}, '202...
# 141  {'2023': {'2023-01': {'post_count': 0}, '2023-...
# 59   {'2022': {'2022-01': {'post_count': 0}, '2022-...
# 134  {'2023': {'2023-01': {'post_count': 0}, '2023-...
# 125  {'2021': {'2021-01': {'post_count': 0}, '2021-...
# 31   {'2020': {'2020-01': {'post_count': 0}, '2020-...
# 130  {'2023': {'2023-01': {'post_count': 0}, '2023-...
# 28   {'2020': {'2020-01': {'post_count': 0}, '2020-...
# 61   {'2020': {'2020-01': {'post_count': 0}, '2020-...
# 49   {'2023': {'2023-01': {'post_count': 0}, '2023-...
# 26   {'2021': {'2021-01': {'post_count': 0}, '2021-...
# 77   {'2023': {'2023-01': {'post_count': 0}, '2023-...
# 51   {'2020': {'2020-01': {'post_count': 493}, '202...
# 112  {'2021': {'2021-01': {'post_count': 0}, '2021-...
# 36   {'2022': {'2022-01': {'post_count': 0}, '2022-...
# 47   {'2020': {'2020-01': {'post_count': 0}, '2020-...
# 27   {'2022': {'2022-01': {'post_count': 0}, '2022-...
# 30   {'2023': {'2023-01': {'post_count': 270}, '202...
# 50   {'2023': {'2023-01': {'post_count': 0}, '2023-...
#
#                                     toxicity_evolution  avg_toxicity  \
# 99   {'2020': {'2020-12': {'avg_toxicity': 0.0339, ...      0.216664
# 142  {'2023': {'2023-01': {'avg_toxicity': 0.2918, ...      0.175611
# 141  {'2023': {'2023-05': {'avg_toxicity': 0.2422, ...      0.173767
# 59   {'2022': {'2022-02': {'avg_toxicity': 0.031, '...      0.149231
# 134  {'2023': {'2023-06': {'avg_toxicity': 0.0382, ...      0.141764
# 125  {'2021': {'2021-05': {'avg_toxicity': 0.041, '...      0.129979
# 31   {'2020': {'2020-06': {'avg_toxicity': 0.0356, ...      0.123047
# 130  {'2023': {'2023-08': {'avg_toxicity': 0.0618, ...      0.120415
# 28   {'2020': {'2020-02': {'avg_toxicity': 0.0497, ...      0.111570
# 61   {'2020': {'2020-10': {'avg_toxicity': 0.203, '...      0.107257
# 49   {'2023': {'2023-03': {'avg_toxicity': 0.1136, ...      0.099625
# 26   {'2021': {'2021-05': {'avg_toxicity': 0.092, '...      0.098385
# 77   {'2023': {'2023-08': {'avg_toxicity': 0.047, '...      0.097606
# 51   {'2020': {'2020-01': {'avg_toxicity': 0.0678, ...      0.096940
# 112  {'2021': {'2021-08': {'avg_toxicity': 0.1246, ...      0.091692
# 36   {'2022': {'2022-04': {'avg_toxicity': 0.2974, ...      0.091469
# 47   {'2020': {'2020-08': {'avg_toxicity': 0.0352, ...      0.090524
# 27   {'2022': {'2022-03': {'avg_toxicity': 0.0565, ...      0.089643
# 30   {'2023': {'2023-01': {'avg_toxicity': 0.1619, ...      0.089523
# 50   {'2023': {'2023-03': {'avg_toxicity': 0.1221, ...      0.087310
#
#                                          sample_topics  \
# 99   [arrest cops police policeman, arrest cops pol...
# 142  [football footballer footballers footballing, ...
# 141  [cannabis drugs marijuana weed, cannabis drugs...
# 59   [crimea nato ukraine ukraines, crimea nato ukr...
# 134  [him role tharman tharmans, nathan tharma thar...
# 125  [comedic humor joke jokes, funny joke jokes la...
# 31   [homosexuality lgbt lgbtq repeal, homophobic h...
# 130  [camera cameras cctv cctvs, camera consent fil...
# 28   [income unemployment wage wages, payouts pays ...
# 61   [religion religions religious secular, christi...
# 49   [beijing china chinas chinese, china chinas pr...
# 26   [smoker smokers smoking tobacco, fires smoke s...
# 77   [driver drivers driving vehicle, bmw driver dr...
# 51   [boom boomer boomers millennial, boomer boomer...
# 112  [burn burned burning burnt, burn burning burns...
# 36   [sandals shoe shoes sneakers, sandals shoe sho...
# 47   [student teacher teachers threatening, classro...
# 27   [feminism feminists genders patriarchy, femini...
# 30   [convicted molested offender sentencing, accus...
# 50   [leases rent renting tenancy, landlord rent re...
#
#                       topic_indices
# 99                        [26, 285]
# 142                      [705, 234]
# 141                      [563, 686]
# 59                  [416, 428, 374]
# 134                      [651, 558]
# 125                      [306, 566]
# 31     [96, 530, 371, 404, 40, 734]
# 130                      [616, 590]
# 28      [125, 646, 71, 8, 300, 461]
# 61                   [73, 386, 457]
# 49             [666, 445, 710, 407]
# 26   [336, 320, 473, 410, 124, 540]
# 77                  [716, 502, 543]
# 51                     [64, 27, 94]
# 112                      [354, 451]
# 36         [485, 695, 472, 57, 220]
# 47              [80, 377, 635, 244]
# 27   [464, 182, 630, 522, 411, 636]
# 30   [608, 146, 325, 390, 709, 126]
# 50              [727, 588, 565, 15]

# %%
# Print results with better formatting
print("\nMeaningful Topic Clusters:")
for _, cluster in cluster_analysis.sort_values('total_posts', ascending=False).head(10).iterrows():
    print(f"\nCluster {cluster['cluster_id']}")
    print(f"Size: {cluster['size']} topics")
    print(f"Total posts: {cluster['total_posts']:,}")
    print(f"Topic diversity: {cluster['topic_diversity']:.2f}")
    print("Unique keywords:", ', '.join(sorted(cluster['unique_keywords'])))
    print("Sample topics:", cluster['sample_topics'])
    print("Temporal evolution:", cluster['temporal_evolution'])
    print("-" * 50)
# Out:
# Meaningful Topic Clusters:
#
# Cluster 56
# Size: 3 topics
# Total posts: 183,014
# Topic diversity: 1.00
# Unique keywords: covid, time, work
# Sample topics: ['covid work', 'covid time work', 'covid work']
# Temporal evolution: {'2021': {'2021-01': {'post_count': 0}, '2021-02': {'post_count': 0}, '2021-03': {'post_count': 0}, '2021-04': {'post_count': 0}, '2021-05': {'post_count': 0}, '2021-06': {'post_count': 0}, '2021-07': {'post_count': 0}, '2021-08': {'post_count': 0}, '2021-09': {'post_count': 64119}, '2021-10': {'post_count': 74628}, '2021-11': {'post_count': 0}, '2021-12': {'post_count': 0}}, '2022': {'2022-01': {'post_count': 0}, '2022-02': {'post_count': 44267}, '2022-03': {'post_count': 0}, '2022-04': {'post_count': 0}, '2022-05': {'post_count': 0}, '2022-06': {'post_count': 0}, '2022-07': {'post_count': 0}, '2022-08': {'post_count': 0}, '2022-09': {'post_count': 0}, '2022-10': {'post_count': 0}, '2022-11': {'post_count': 0}, '2022-12': {'post_count': 0}}}
# --------------------------------------------------
#
# Cluster 42
# Size: 4 topics
# Total posts: 150,279
# Topic diversity: 1.25
# Unique keywords: employment, job, jobs, pay, work
# Sample topics: ['job work', 'job pay work', 'job work']
# Temporal evolution: {'2020': {'2020-01': {'post_count': 0}, '2020-02': {'post_count': 804}, '2020-03': {'post_count': 0}, '2020-04': {'post_count': 0}, '2020-05': {'post_count': 0}, '2020-06': {'post_count': 0}, '2020-07': {'post_count': 0}, '2020-08': {'post_count': 53387}, '2020-09': {'post_count': 53876}, '2020-10': {'post_count': 0}, '2020-11': {'post_count': 42212}, '2020-12': {'post_count': 0}}}
# --------------------------------------------------
#
# Cluster 0
# Size: 22 topics
# Total posts: 141,317
# Topic diversity: 1.23
# Unique keywords: coronavirus, covid, covid19, covid19s, covidiots, covids, fishery, flu, infect, infected, infectious, jurong, outbreak, pandemic, precovid, quarantine, quarantined, quarantines, singapores, sinovac, vaccinated, vaccination, vaccinations, vaccine, vaccines, virus, viruses
# Sample topics: ['covid vaccinated', 'covid vaccinated vaccination vaccine', 'covid covid19']
# Temporal evolution: {'2021': {'2021-01': {'post_count': 0}, '2021-02': {'post_count': 0}, '2021-03': {'post_count': 0}, '2021-04': {'post_count': 0}, '2021-05': {'post_count': 8098}, '2021-06': {'post_count': 2221}, '2021-07': {'post_count': 62546}, '2021-08': {'post_count': 62385}, '2021-09': {'post_count': 0}, '2021-10': {'post_count': 0}, '2021-11': {'post_count': 0}, '2021-12': {'post_count': 0}}, '2020': {'2020-01': {'post_count': 522}, '2020-02': {'post_count': 0}, '2020-03': {'post_count': 0}, '2020-04': {'post_count': 949}, '2020-05': {'post_count': 0}, '2020-06': {'post_count': 0}, '2020-07': {'post_count': 0}, '2020-08': {'post_count': 484}, '2020-09': {'post_count': 0}, '2020-10': {'post_count': 401}, '2020-11': {'post_count': 0}, '2020-12': {'post_count': 0}}, '2022': {'2022-01': {'post_count': 0}, '2022-02': {'post_count': 1391}, '2022-03': {'post_count': 802}, '2022-04': {'post_count': 331}, '2022-05': {'post_count': 0}, '2022-06': {'post_count': 0}, '2022-07': {'post_count': 0}, '2022-08': {'post_count': 0}, '2022-09': {'post_count': 0}, '2022-10': {'post_count': 454}, '2022-11': {'post_count': 0}, '2022-12': {'post_count': 0}}, '2023': {'2023-01': {'post_count': 381}, '2023-02': {'post_count': 0}, '2023-03': {'post_count': 0}, '2023-04': {'post_count': 0}, '2023-05': {'post_count': 352}, '2023-06': {'post_count': 0}, '2023-07': {'post_count': 0}, '2023-08': {'post_count': 0}, '2023-09': {'post_count': 0}, '2023-10': {'post_count': 0}, '2023-11': {'post_count': 0}, '2023-12': {'post_count': 0}}}
# --------------------------------------------------
#
# Cluster 79
# Size: 2 topics
# Total posts: 82,375
# Topic diversity: 1.50
# Unique keywords: dont, people, work
# Sample topics: ['dont work', 'dont people']
# Temporal evolution: {'2020': {'2020-01': {'post_count': 0}, '2020-02': {'post_count': 37608}, '2020-03': {'post_count': 0}, '2020-04': {'post_count': 0}, '2020-05': {'post_count': 44767}, '2020-06': {'post_count': 0}, '2020-07': {'post_count': 0}, '2020-08': {'post_count': 0}, '2020-09': {'post_count': 0}, '2020-10': {'post_count': 0}, '2020-11': {'post_count': 0}, '2020-12': {'post_count': 0}}}
# --------------------------------------------------
#
# Cluster 9
# Size: 10 topics
# Total posts: 65,735
# Topic diversity: 2.10
# Unique keywords: cantonese, chinese, chineses, chinesethis, covid, dezzzzzzzzzzzzzzzzzzzzzzzzzzz, dialects, hualalalalalal, huat, idiom, korean, languages, mandarin, poem, proverbial, shank, taiwanese, translate, translates, translation, zhongguo
# Sample topics: ['chinese covid', 'cantonese chinese dialects mandarin', 'dezzzzzzzzzzzzzzzzzzzzzzzzzzz mandarin poem zhongguo']
2022-01': {'post_count': 569}, '2022-02': {'post_count': 0}, '2022-03': {'post_count': 1481}, '2022-04': {'post_count': 581}, '2022-05': {'post_count': 0}, '2022-06': {'post_count': 0}, '2022-07': {'post_count': 0}, '2022-08': {'post_count': 865}, '2022-09': {'post_count': 0}, '2022-10': {'post_count': 0}, '2022-11': {'post_count': 0}, '2022-12': {'post_count': 0}}, '2021': {'2021-01': {'post_count': 403}, '2021-02': {'post_count': 0}, '2021-03': {'post_count': 0}, '2021-04': {'post_count': 0}, '2021-05': {'post_count': 0}, '2021-06': {'post_count': 354}, '2021-07': {'post_count': 616}, '2021-08': {'post_count': 790}, '2021-09': {'post_count': 0}, '2021-10': {'post_count': 0}, '2021-11': {'post_count': 0}, '2021-12': {'post_count': 0}}}
# --------------------------------------------------

# %%
# save data
cluster_analysis.to_csv('D:\\Github_Repos\\dsa4264\\/data/topic_clusters.csv', index=False)

# %%
cluster = pd.read_csv('D:\\Github_Repos\\dsa4264\\/data/topic_clusters.csv')

# %%
cluster.head()
# Out:
#    cluster_id  size  total_posts  \
# 0           0    22       141317
# 1           1    20        14679
# 2           2    17         9207
# 3           3    15         8096
# 4           4    12         7217
#
#                                      unique_keywords  topic_diversity  \
# 0  ['viruses', 'covids', 'quarantines', 'coronavi...         1.227273
# 1  ['hdb', 'asset', 'sale', 'sell', 'rents', 'mor...         1.350000
# 2  ['sgs', 'sgsecure', 'sgreans', 'sgd', 'sgraw',...         0.764706
# 3  ['bikers', 'cyclists', 'cyclist', 'motorcyclis...         1.133333
# 4  ['masked', 'mask', 'maskless', 'masking', 'mas...         0.750000
#
#                                   temporal_evolution  \
# 0  {'2021': {'2021-01': {'post_count': 0}, '2021-...
# 1  {'2021': {'2021-01': {'post_count': 384}, '202...
# 2  {'2022': {'2022-01': {'post_count': 0}, '2022-...
# 3  {'2023': {'2023-01': {'post_count': 291}, '202...
# 4  {'2020': {'2020-01': {'post_count': 0}, '2020-...
#
#                                   toxicity_evolution  avg_toxicity  \
# 0  {'2021': {'2021-05': {'avg_toxicity': 0.0441, ...      0.050925
# 1  {'2021': {'2021-01': {'avg_toxicity': 0.0461, ...      0.086916
# 2  {'2022': {'2022-07': {'avg_toxicity': 0.0595, ...      0.049124
# 3  {'2023': {'2023-01': {'avg_toxicity': 0.0416, ...      0.056845
# 4  {'2020': {'2020-08': {'avg_toxicity': 0.0425, ...      0.086982
#
#                                        sample_topics  \
# 0  ['covid vaccinated', 'covid vaccinated vaccina...
# 1  ['bto btos hdb housing', 'btos flats hdb valua...
# 2  ['rsg sgraw sgs', 'sgeans sgraw sgs', 'sgraw s...
# 3  ['driving pedestrian pedestrians traffic', 'dr...
# 4  ['mask masking maskoff masks', 'mask maskless ...
#
#                                        topic_indices
# 0  [192, 321, 66, 195, 514, 388, 637, 653, 529, 8...
# 1  [194, 707, 196, 519, 712, 649, 703, 278, 603, ...
# 2  [481, 389, 425, 201, 75, 409, 587, 655, 559, 6...
# 3  [577, 70, 264, 9, 235, 14, 591, 497, 689, 52, ...
# 4  [128, 385, 223, 132, 267, 109, 302, 210, 406, ...
